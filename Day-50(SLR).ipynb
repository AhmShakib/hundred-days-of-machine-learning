# %%
import pandas as pd 
import numpy as np 

df=pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(X,y ,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()

lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

y_pred=lr.predict(X_test)

r2_score(y_test,y_pred)
# Out:
# 0.7774721122516276

# %%
c=lr.intercept_,
m=lr.coef_
c,m
# Out:
# ((-0.9998951779221357,), array([0.57111357]))

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X,lr.predict(X),color='green')

# %%
# y= mx + c
#note here m is the slope of the line which also represents the weight of the variable x(cgpa) 
#because if we increase the value of m ,y will also increase
